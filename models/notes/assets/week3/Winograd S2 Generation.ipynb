# %% [markdown]
# ## Winograd Explanation Generation
#
# We are currently using a system without pointer-generator

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
data_path = '/home/anie/OpenNMT-py/data/winograd/'

df = pd.read_csv(data_path+'s1_ref_hyp.csv')

# %%
df.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row0_col0 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row0_col1 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row0_col2 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row0_col3 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row1_col0 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row1_col1 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row1_col2 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row1_col3 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row2_col0 {
#             text-align:  left;
#         }    #T_e2e2657c_bd01_11e8_b89d_2c4d54468980row2_col1 {
# ...
